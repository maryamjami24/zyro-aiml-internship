# %%
print("Hello! Welcome to my AI/ML Internship.")
print("Week 01 - Python and Data Science Basics")
# Out:
# Hello! Welcome to my AI/ML Internship.
# Week 01 - Python and Data Science Basics

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
# Out:
# [10 20 30 40 50]

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print("Original Array:", numbers)
print("Addition:", numbers + 10)
print("Multiplication:", numbers * 2)
# Out:
# Original Array: [10 20 30 40 50]
# Addition: [20 30 40 50 60]
# Multiplication: [ 20  40  60  80 100]
